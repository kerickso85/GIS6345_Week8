# %%
import geopandas
import matplotlib.pyplot as plt

filename="StreetCenterlines.shp"
centerlines=geopandas.read_file(filename)
#print('StreetCenterlines.shp imported as type: ',type(centerlines)) #validation
#print(centerlines.shape) #debug statement
print(centerlines.head()) #a glimpse of what we're looking at


#create 20x20 plot with the shape lengths colorized by percentile
#increased line width and a different color map
centerlines.plot(figsize=(20,20), column='LENGTH', scheme='percentiles', 
                 linewidth=2.5, legend=True, cmap='cividis_r')


plt.show() #display the shapefile contents
# Out:
#    OBJECTID  FNODE_  TNODE_  LPOLY_  RPOLY_      LENGTH  ROADSCL_  ROADSCL_ID  \
# 0         1       0       0       0       0  497.559782         0           0
# 1         2       0       0       0       0  592.088780         0           0
# 2         3       0       0       0       0  186.964606         0           0
# 3         4       0       0       0       0  472.577269         0           0
# 4         5       0       0       0       0  296.057598         0           0
#
#   DXF_LAYER  DXF_ELEVAT   TYPE              NAME   OWNER STREETNAME  \
# 0    PUBLIC         0.0  PAVED  SHERBOURNE PLACE  PUBLIC       None
# 1    PUBLIC         0.0  PAVED  WIMBLEDON CIRCLE  PUBLIC       None
# 2    PUBLIC         0.0  PAVED     MIDLAND DRIVE  PUBLIC       None
# 3    PUBLIC         0.0  PAVED  SHERBOURNE PLACE  PUBLIC       None
# 4    PUBLIC         0.0  PAVED     VESPER STREET  PUBLIC       None
#
#     SHAPE_len                                           geometry
# 0  497.559846  LINESTRING (719642.560 2979388.780, 719603.330...
# 1  592.088696  LINESTRING (719350.609 2979004.405, 719331.851...
# 2  186.964619  LINESTRING (720323.492 2978958.952, 720315.540...
# 3  472.577194  LINESTRING (719350.609 2979004.405, 719349.825...
# 4  296.057523  LINESTRING (719136.857 2978587.601, 719168.780...
